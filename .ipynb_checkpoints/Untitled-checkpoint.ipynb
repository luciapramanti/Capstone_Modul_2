# %%
import numpy as np
import pandas as pd


df = pd.read_csv("Transjakarta.csv")
df.head()
# Out:
#           transID         payCardID payCardBank      payCardName payCardSex  \
# 0  EIIW227B8L34VB   180062659848800      emoney   Bajragin Usada          M
# 1  LGXO740D2N47GZ  4885331907664776         dki     Gandi Widodo          F
# 2  DJWR385V2U57TO  4996225095064169         dki    Emong Wastuti          F
# 3  JTUZ800U7C86EH      639099174703       flazz     Surya Wacana          F
# 4  VMLO535V7F95NJ      570928206772       flazz  Embuh Mardhiyah          M
#
#    payCardBirthDate corridorID                              corridorName  \
# 0              2008          5                     Matraman Baru - Ancol
# 1              1997         6C  Stasiun Tebet - Karet via Patra Kuningan
# 2              1992        R1A                        Pantai Maju - Kota
# 3              1978        11D       Pulo Gebang - Pulo Gadung 2 via PIK
# 4              1982         12                     Tanjung Priok - Pluit
#
# ...

# %%
df['tapInTime'] = pd.to_datetime(df['tapInTime'])
df['tapOutTime'] = pd.to_datetime(df['tapOutTime'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17164\852029875.py in ?()
#       1 df['tapInTime'] = pd.to_datetime(df['tapInTime'])
#       2 df['tapOutTime'] = pd.to_datetime(df['tapOutTime'])
#       3
# ----> 4 df.Dtype()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Dtype'

# %%
##### change data date & time
- secara default pandas akan membaca kolom selain Numerik sebagai objek

tap in time ==> masih object (karena ada ":" atau "_" nya)
extract tap in time dari object jadi waktu.
misal mau bulan doang, atau harinya doang

kolom tanggal bisa diekstraksi kalau datanya berformat datetime. sedangkan disini masih object
maka perlu dilakukan konversi

# %%
#### alt 1
- menggunakan parse_dates = ["nama kolom"] ketika awal membaca file

# %%
#### alt 2
- menggunakan fungsi .astype()
- digunakan untuk mengubah tipe data, tidak terbatas pada date time
- .astype(datetime)

# %%
#### alt 3
-menggunakan fungsi pd.to_datetime(nama_kolom)
df = pd.read_csv("data.csv")
df["nama_kolom"] = pd.to_datetime(nama_kolom) ==> harus dimasukin ke nama kolom

# %%
tanggal = pd.Series([
"31-03-2022",
"01-04-2022",
"02-04-2022", 
"17-08-2022",
"31-10-2022",
"03-04-1011"])

tanggal

# %%
tgl = pd.Series ([
    "01-maret-2005",
    "july/17/2017",
    "Agustus-20-2021",
    "20-september-2003",
    "19-august-2016",
    "20/May/2004",
    "2021-02-15",
    "07/25/2000",
    "24-12-2022",
    "januari-01-2023"
])

tgl

# %%
# !pip install dateparser

# %%
import dateparser

# %%
tgl.apply(dateparser.parse)

# %% [markdown]
# analisis data dengan tabular

# %% [markdown]
# -crosstab
# -groupby
# -pivot table

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ### 1. business question : sub category apa yang memiliki penjualan (items) tertinggi?

# %% [markdown]
# df["sub_category"].value_counts()

# %% [markdown]
# pd.crosstab(df["sub_category"], columns="Jumlah")

# %% [markdown]
# ![image.png](attachment:dc2e0f4c-d451-4607-bbdc-8ab5bf122eb5.png)
